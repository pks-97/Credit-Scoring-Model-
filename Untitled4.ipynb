# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import Imputer
start = 12
end = 13
# file = pd.read_csv("hmeq.csv")
X = file.values
imputer = Imputer(missing_values="NaN",strategy="mean",axis=0)
imputer = imputer.fit(X[:,start:end])
X[:,start:end] = imputer.transform(X[:,start:end])

# %%
file = pd.read_csv("hmeq.csv")

# %%
X.shape
# Out:
# (5960, 13)

# %%
file["DEROG"].median()
# Out:
# 0.0

# %%
file["MORTDUE"] = X[:,2]

# %%
file["VALUE"] = X[:,3]

# %%
file["YOJ"] = X[:,6]

# %%
file["DEBTINC"] = X[:,12]

# %%
file
# Out:
#       BAD   LOAN  MORTDUE   VALUE   REASON      JOB      YOJ DEROG DELINQ  \
# 0       1   1100    25860   39025  HomeImp    Other     10.5     0      0
# 1       1   1300    70053   68400  HomeImp    Other        7     0      2
# 2       1   1500    13500   16700  HomeImp    Other        4     0      0
# 3       1   1500  73760.8  101776      NaN      NaN  8.92227     0      0
# 4       0   1700    97800  112000  HomeImp   Office        3     0      0
# 5       1   1700    30548   40320  HomeImp    Other        9     0      0
# 6       1   1800    48649   57037  HomeImp    Other        5     3      2
# 7       1   1800    28502   43034  HomeImp    Other       11     0      0
# 8       1   2000    32700   46740  HomeImp    Other        3     0      2
# 9       1   2000  73760.8   62250  HomeImp    Sales       16     0      0
# 10      1   2000    22608  101776      NaN      NaN       18     0      0
# 11      1   2000    20627   29800  HomeImp   Office       11     0      1
# ...

# %%
d = pd.read_csv("hmeq.csv")

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import Imputer
start = 7
end = 8
# file = pd.read_csv("hmeq.csv")
X = d.values
imputer = Imputer(missing_values="NaN",strategy="median",axis=0)
imputer = imputer.fit(X[:,start:end])
X[:,start:end] = imputer.transform(X[:,start:end])

# %%
file["DEROG"] = X[:,7]

# %%
file
# Out:
#       BAD   LOAN  MORTDUE   VALUE REASON  JOB      YOJ DEROG DELINQ    CLAGE  \
# 0       1   1100    25860   39025      1    0     10.5     0      0  94.3667
# 1       1   1300    70053   68400      1    0        7     0      2  121.833
# 2       1   1500    13500   16700      1    0        4     0      0  149.467
# 3       1   1500  73760.8  101776    NaN  NaN  8.92227     0      0  179.766
# 4       0   1700    97800  112000      1    2        3     0      0  93.3333
# 5       1   1700    30548   40320      1    0        9     0      0  101.466
# 6       1   1800    48649   57037      1    0        5     3      2     77.1
# 7       1   1800    28502   43034      1    0       11     0      0   88.766
# 8       1   2000    32700   46740      1    0        3     0      2  216.933
# 9       1   2000  73760.8   62250      1    4       16     0      0    115.8
# 10      1   2000    22608  101776    NaN  NaN       18     0      0  179.766
# ...

# %%
from sklearn.linear_model import LogisticRegression
linreg = LogisticRegression(multi_class='ovr')
file.loc[file['REASON'] == 'HomeImp', 'REASON'] = 1
file.loc[file['REASON'] == 'DebtCon', 'REASON'] = 0
file.loc[file['JOB'] == 'Other', 'JOB'] = 0
file.loc[file['JOB'] == 'Mgr', 'JOB'] = 1
file.loc[file['JOB'] == 'Office', 'JOB'] = 2
file.loc[file['JOB'] == 'ProfExe', 'JOB'] = 3
file.loc[file['JOB'] == 'Sales', 'JOB'] = 4
file.loc[file['JOB'] == 'Self', 'JOB'] = 5
file_without_null = file.dropna()

# print(data_without_null)

train_file_y = file_without_null.iloc[:,4]
train_file_part_1 = file_without_null.iloc[:,0:4]
train_file_part_2 = file_without_null.iloc[:,6:]
# train_data_part_2
train_file_x = train_file_part_1.join(train_file_part_2)
# train_data_x
# print(train_file_y)
linreg.fit(train_file_x,train_file_y)

test_file_part_1 = file.iloc[:,0:4]
test_file_part_2 = file.iloc[:,6:]
test_file_x = test_file_part_1.join(test_file_part_2)
# print(test_data_x['VALUE'].mean())
# test_file_x['JOB'].replace(np.NaN, test_file_x['VALUE'].mean()).head(15)
# print(test_data_x['VALUE'])
# print(test_file_x)
value['REASON'] = pd.DataFrame(linreg.predict(test_file_x))

file.REASON.fillna(value.REASON,inplace=True)

print(file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-8439a6a4a067> in <module>
#      20 # train_data_x
#      21 # print(train_file_y)
# ---> 22 linreg.fit(train_file_x,train_file_y)
#      23
#      24 test_file_part_1 = file.iloc[:,0:4]
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1219         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype,
#    1220                          order="C")
# -> 1221         check_classification_targets(y)
#    1222         self.classes_ = np.unique(y)
#    1223         n_samples, n_features = X.shape
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     169     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
# ...
